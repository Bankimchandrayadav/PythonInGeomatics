# %% [markdown]
# # [1] About
#
# <img style="float: right;" src="../BCYadav_about.png">
#
#  - This notebook is a part of tutorial series prepared by B. C. Yadav, Research Scholar @ IIT Roorkee.
#  - ORCID iD: https://orcid.org/0000-0001-7288-0551
#  - Google Scholar: https://scholar.google.com/citations?user=6fJpxxQAAAAJ&hl=en&authuser=1
#  - Github: https://github.com/Bankimchandrayadav/PythonInGeomatics
#  - Twitter: https://twitter.com/DrBCY
#  - **Recent Publication:** https://rmets.onlinelibrary.wiley.com/doi/10.1002/joc.6562
#  - This notebook demonstrates the [resampling of one tiff file from one resolution to another]
# ---

# %% [markdown]
# # [2] First time usage for conda users

# %%
# !conda install -c conda-forge gdal -y

# %% [markdown]
# # [3] First time usage for pip users

# %%
# !pip install "../03_wheels/GDAL-3.1.4-cp38-cp38-win_amd64.whl"

# %% [markdown]
# # [4] Importing libraries

# %%
import gdal 
import os 
import shutil 
import time 
import numpy as np 
from tqdm.notebook import tqdm as td
start = time.time()  # will be used to measure the effectiveness of automation

# %% [markdown]
# # [5] Creating routine functions

# %%
def fresh(where):
    if os.path.exists(where):
        shutil.rmtree(where)
        os.mkdir(where)
    else:
        os.mkdir(where)

# %% [markdown]
# # [6] Read files

# %% [markdown]
# ## [6.1] Specify input directory

# %%
rootDir = "../02_data/04_reprojected"

# %% [markdown]
# ## [6.2] Read files from input directory

# %%
# create an empty list 
rasters = [] 

# loop starts here 
for dirname, subdirnames, filenames in os.walk(rootDir):

    # search message
    print('Searched in directory: {}\n'.format(dirname))

    # subloop starts here
    for filename in filenames:

        # get complete file name 
        filename = os.path.join(dirname, filename)

        # add name one by one to the above list (rasters)
        rasters.append(filename)

# print success message
print('Files read')
# Out:
# Searched in directory: ../02_data/04_reprojected
#
# Files read

# %% [markdown]
# ## [6.3] Check the input data

# %%
print('First file in sequence:', rasters[0])
# Out:
# First file in sequence: ../02_data/04_reprojected\2000-01-01T00_reprojected.tif

# %%
print('Last file in sequence:', rasters[-1])
# Out:
# Last file in sequence: ../02_data/04_reprojected\2000-02-11T15_reprojected.tif

# %% [markdown]
# # [7] Resampling to a resolution 5000m x 5000m

# %% [markdown]
# ## [7.1] Specify output directory:

# %%
outDir = "../02_data/05_resampled/"

# %% [markdown]
# ## [7.2] Delete any existing or old files

# %%
fresh(where=outDir)

# %% [markdown]
# ## [7.3] Check output directory [optional]

# %%
# os.startfile(os.path.realpath(outDir))

# %% [markdown]
# ## [7.4] Resampling to 5000m x 5000m

# %%
# loop starts here 
for i in td(range(0, len(rasters)), desc='Resampling'):

    # extract out file name from the complete path 
    fileName = rasters[i].split('\\')[1].split('.')[0]  

    # specify outfile name 
    outName = outDir + "{}_resampled.tif".format(fileName)  # outfile name

    # resample to 5000m x 5000m resolution in UTM44N projection
    gdal.Warp(
        destNameOrDestDS=outName,       # out file name 
        srcDSOrSrcDSTab=rasters[i],     # source file name 
        xRes = 5000,                    # new x resolution 
        yRes = 5000,                    # new y resolution 
    )
# Out:
# HBox(children=(HTML(value='Resampling'), FloatProgress(value=0.0, max=1000.0), HTML(value='')))

# %% [markdown]
# # [8] Time elapsed

# %%
end = time.time()
print('Time elapsed:', np.round(end-start ,2), 'secs')
# Out:
# Time elapsed: 98.57 secs

# %% [markdown]
# # [9] See results [1000 reprojected files, optional]

# %%
# os.startfile(os.path.realpath(outDir))

# %% [markdown]
# ---
# # End of fourth tutorial
# ---
